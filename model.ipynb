# %%
import kagglehub

# Download latest version
path = kagglehub.dataset_download("iamsumat/spotify-top-2000s-mega-dataset",
                                 path="./data")

print("Path to dataset files:", path)
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# File ~/uni/ASI/Music-Genre-Clustering/.venv/lib/python3.12/site-packages/kagglehub/exceptions.py:66, in kaggle_api_raise_for_status(response, resource_handle)
#      65 try:
# ---> 66     response.raise_for_status()
#      67 except requests.HTTPError as e:
#
# File ~/.cache/uv/archive-v0/0xYK2sMJonbN4u3c-DEyH/lib/python3.12/site-packages/requests/models.py:1026, in Response.raise_for_status(self)
#    1025 if http_error_msg:
# -> 1026     raise HTTPError(http_error_msg, response=self)
#
# HTTPError: 404 Client Error: Not Found for url: https://www.kaggle.com/api/v1/datasets/download/iamsumat/spotify-top-2000s-mega-dataset?dataset_version_number=5&file_name=./data
#
# The above exception was the direct cause of the following exception:
#
# KaggleApiHTTPError                        Traceback (most recent call last)
# Cell In[4], line 4
#       1 import kagglehub
#       3 # Download latest version
# ----> 4 path = kagglehub.dataset_download("iamsumat/spotify-top-2000s-mega-dataset",
#       5                                  path="./data")
#       7 print("Path to dataset files:", path)
#
# File ~/uni/ASI/Music-Genre-Clustering/.venv/lib/python3.12/site-packages/kagglehub/datasets.py:43, in dataset_download(handle, path, force_download)
#      41 h = parse_dataset_handle(handle)
#      42 logger.info(f"Downloading Dataset: {h.to_url()} ...", extra={**EXTRA_CONSOLE_BLOCK})
# ---> 43 path, _ = registry.dataset_resolver(h, path, force_download=force_download)
#      44 return path
#
# File ~/uni/ASI/Music-Genre-Clustering/.venv/lib/python3.12/site-packages/kagglehub/registry.py:28, in MultiImplRegistry.__call__(self, *args, **kwargs)
#      26 for impl in reversed(self._impls):
#      27     if impl.is_supported(*args, **kwargs):
# ---> 28         return impl(*args, **kwargs)
#      29     else:
#      30         fails.append(type(impl).__name__)
#
# File ~/uni/ASI/Music-Genre-Clustering/.venv/lib/python3.12/site-packages/kagglehub/resolver.py:29, in Resolver.__call__(self, handle, path, force_download)
#      15 def __call__(
#      16     self, handle: T, path: Optional[str] = None, *, force_download: Optional[bool] = False
#      17 ) -> tuple[str, Optional[int]]:
#      18     """Resolves a handle into a path with the requested file(s) and the resource's version number.
#      19
#      20     Args:
#    (...)     27         Some cases where version number might be missing: Competition datasource, API-based models.
#      28     """
# ---> 29     path, version = self._resolve(handle, path, force_download=force_download)
#      31     # Note handles are immutable, so _resolve() could not have altered our reference
#      32     register_datasource_access(handle, version)
#
# File ~/uni/ASI/Music-Genre-Clustering/.venv/lib/python3.12/site-packages/kagglehub/http_resolver.py:122, in DatasetHttpResolver._resolve(self, h, path, force_download)
#     119 if path:
#     120     # Downloading a single file.
#     121     os.makedirs(os.path.dirname(out_path), exist_ok=True)
# --> 122     api_client.download_file(url_path, out_path, h, extract_auto_compressed_file=True)
#     123 else:
#     124     # TODO(b/345800027) Implement parallel download when < 25 files in databundle.
#     125     # Downloading the full archived bundle.
#     126     archive_path = get_cached_archive_path(h)
#
# File ~/uni/ASI/Music-Genre-Clustering/.venv/lib/python3.12/site-packages/kagglehub/clients.py:182, in KaggleApiV1Client.download_file(self, path, out_file, resource_handle, cached_path, extract_auto_compressed_file)
#     174 url = self._build_url(path)
#     175 with requests.get(
#     176     url,
#     177     headers={"User-Agent": get_user_agent()},
#    (...)    180     timeout=(DEFAULT_CONNECT_TIMEOUT, DEFAULT_READ_TIMEOUT),
#     181 ) as response:
# --> 182     kaggle_api_raise_for_status(response, resource_handle)
#     184     total_size = int(response.headers["Content-Length"]) if "Content-Length" in response.headers else None
#     185     size_read = 0
#
# File ~/uni/ASI/Music-Genre-Clustering/.venv/lib/python3.12/site-packages/kagglehub/exceptions.py:106, in kaggle_api_raise_for_status(response, resource_handle)
#      97     message = (
#      98         f"{response.status_code} Client Error."
#      99         "\n\n"
#    (...)    102         "Please make sure you specified the correct resource identifiers."
#     103     )
#     105 # Default handling
# --> 106 raise KaggleApiHTTPError(message, response=response) from e
#
# KaggleApiHTTPError: 404 Client Error.
#
# Resource not found at URL: https://www.kaggle.com/datasets/iamsumat/spotify-top-2000s-mega-dataset/versions/5
# The server reported the following issues: Dataset not found
# Please make sure you specified the correct resource identifiers.
